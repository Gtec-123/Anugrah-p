# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
dataset=pd.read_csv('/content/Financial-Data.csv')

# %%
dataset.head()
# Out:
#    Entry_id  age  pay_schedule  home_owner  income  months_employed  \
# 0   7629673   40     bi-weekly           1    3135                0
# 1   3560428   61        weekly           0    3180                0
# 2   6934997   23        weekly           0    1540                6
# 3   5682812   40     bi-weekly           0    5230                0
# 4   5335819   33  semi-monthly           0    3590                0
#
#    years_employed  current_address_year  personal_account_m  \
# 0               3                     3                   6
# 1               6                     3                   2
# 2               0                     0                   7
# 3               6                     1                   2
# 4               5                     2                   2
#
#    personal_account_y  ...  amount_requested  risk_score  risk_score_2  \
# 0                   2  ...               550       36200      0.737398
# 1                   7  ...               600       30150      0.738510
# 2                   1  ...               450       34550      0.642993
# 3                   7  ...               700       42150      0.665224
# 4                   8  ...              1100       53850      0.617361
#
#    risk_score_3  risk_score_4  risk_score_5  ext_quality_score  \
# 0      0.903517      0.487712      0.515977           0.580918
# 1      0.881027      0.713423      0.826402           0.730720
# 2      0.766554      0.595018      0.762284           0.531712
# 3      0.960832      0.767828      0.778831           0.792552
# 4      0.857560      0.613487      0.665523           0.744634
#
#    ext_quality_score_2  inquiries_last_month  e_signed
# 0             0.380918                    10         1
# 1             0.630720                     9         0
# 2             0.531712                     7         0
# 3             0.592552                     8         1
# 4             0.744634                    12         0
#
# [5 rows x 21 columns]

# %%
dataset.shape
# Out:
# (17908, 21)

# %%
dataset.columns
# Out:
# Index(['Entry_id', 'age', 'pay_schedule', 'home_owner', 'income',
#        'months_employed', 'years_employed', 'current_address_year',
#        'personal_account_m', 'personal_account_y', 'has_debt',
#        'amount_requested', 'risk_score', 'risk_score_2', 'risk_score_3',
#        'risk_score_4', 'risk_score_5', 'ext_quality_score',
#        'ext_quality_score_2', 'inquiries_last_month', 'e_signed'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17908 entries, 0 to 17907
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Entry_id              17908 non-null  int64
#  1   age                   17908 non-null  int64
#  2   pay_schedule          17908 non-null  object
#  3   home_owner            17908 non-null  int64
#  4   income                17908 non-null  int64
#  5   months_employed       17908 non-null  int64
#  6   years_employed        17908 non-null  int64
#  7   current_address_year  17908 non-null  int64
#  8   personal_account_m    17908 non-null  int64
#  9   personal_account_y    17908 non-null  int64
#  10  has_debt              17908 non-null  int64
#  11  amount_requested      17908 non-null  int64
#  12  risk_score            17908 non-null  int64
#  13  risk_score_2          17908 non-null  float64
#  14  risk_score_3          17908 non-null  float64
#  15  risk_score_4          17908 non-null  float64
#  16  risk_score_5          17908 non-null  float64
#  17  ext_quality_score     17908 non-null  float64
#  18  ext_quality_score_2   17908 non-null  float64
#  19  inquiries_last_month  17908 non-null  int64
#  20  e_signed              17908 non-null  int64
# dtypes: float64(6), int64(14), object(1)
# memory usage: 2.9+ MB

# %%
dataset.describe()
# Out:
#            Entry_id           age    home_owner        income  \
# count  1.790800e+04  17908.000000  17908.000000  17908.000000
# mean   5.596978e+06     43.015412      0.425173   3657.214653
# std    2.562473e+06     11.873107      0.494383   1504.890063
# min    1.111398e+06     18.000000      0.000000    905.000000
# 25%    3.378999e+06     34.000000      0.000000   2580.000000
# 50%    5.608376e+06     42.000000      0.000000   3260.000000
# 75%    7.805624e+06     51.000000      1.000000   4670.000000
# max    9.999874e+06     96.000000      1.000000   9985.000000
#
#        months_employed  years_employed  current_address_year  \
# count     17908.000000    17908.000000          17908.000000
# mean          1.186006        3.526860              3.584711
# std           2.400897        2.259732              2.751937
# min           0.000000        0.000000              0.000000
# 25%           0.000000        2.000000              2.000000
# 50%           0.000000        3.000000              3.000000
# 75%           1.000000        5.000000              5.000000
# max          11.000000       16.000000             12.000000
#
#        personal_account_m  personal_account_y      has_debt  amount_requested  \
# count        17908.000000        17908.000000  17908.000000      17908.000000
# mean             3.427183            3.503350      0.795399        950.446449
# std              2.216440            1.955568      0.403421        698.543683
# min              0.000000            0.000000      0.000000        350.000000
# 25%              2.000000            2.000000      1.000000        600.000000
# 50%              2.000000            3.000000      1.000000        700.000000
# 75%              5.000000            4.000000      1.000000       1100.000000
# max             11.000000           15.000000      1.000000      10200.000000
#
#          risk_score  risk_score_2  risk_score_3  risk_score_4  risk_score_5  \
# count  17908.000000  17908.000000  17908.000000  17908.000000  17908.000000
# mean   61086.302211      0.690878      0.878276      0.583155      0.718252
# std    15394.255020      0.090470      0.054563      0.125061      0.120697
# min     2100.000000      0.023258      0.451371      0.016724      0.153367
# 25%    49350.000000      0.640993      0.850882      0.500208      0.633708
# 50%    61200.000000      0.699561      0.881004      0.588208      0.725113
# 75%    72750.000000      0.752887      0.912608      0.672395      0.806681
# max    99750.000000      0.999997      0.999024      0.978932      0.996260
#
#        ext_quality_score  ext_quality_score_2  inquiries_last_month  \
# count       17908.000000         17908.000000          17908.000000
# mean            0.623112             0.622068              6.457226
# std             0.139729             0.139898              3.673093
# min             0.010184             0.006622              1.000000
# 25%             0.521735             0.519677              4.000000
# 50%             0.625944             0.622973              6.000000
# 75%             0.729841             0.728940              8.000000
# max             0.970249             0.966953             30.000000
#
#            e_signed
# count  17908.000000
# mean       0.538251
# std        0.498549
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
dataset.isnull().values.any()
# Out:
# np.False_

# %%
dataset.isnull().values.sum()
# Out:
# np.int64(0)

# %%
dataset.select_dtypes(include='object').columns
# Out:
# Index(['pay_schedule'], dtype='object')

# %%
len(dataset.select_dtypes(include='object').columns)
# Out:
# 1

# %%
dataset['pay_schedule'].unique()
# Out:
# array(['bi-weekly', 'weekly', 'semi-monthly', 'monthly'], dtype=object)

# %%
dataset['pay_schedule'].nunique()
# Out:
# 4

# %%
dataset.shape
# Out:
# (17908, 21)

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.head()
# Out:
#    Entry_id  age  home_owner  income  months_employed  years_employed  \
# 0   7629673   40           1    3135                0               3
# 1   3560428   61           0    3180                0               6
# 2   6934997   23           0    1540                6               0
# 3   5682812   40           0    5230                0               6
# 4   5335819   33           0    3590                0               5
#
#    current_address_year  personal_account_m  personal_account_y  has_debt  \
# 0                     3                   6                   2         1
# 1                     3                   2                   7         1
# 2                     0                   7                   1         1
# 3                     1                   2                   7         1
# 4                     2                   2                   8         1
#
#    ...  risk_score_3  risk_score_4  risk_score_5  ext_quality_score  \
# 0  ...      0.903517      0.487712      0.515977           0.580918
# 1  ...      0.881027      0.713423      0.826402           0.730720
# 2  ...      0.766554      0.595018      0.762284           0.531712
# 3  ...      0.960832      0.767828      0.778831           0.792552
# 4  ...      0.857560      0.613487      0.665523           0.744634
#
#    ext_quality_score_2  inquiries_last_month  e_signed  pay_schedule_monthly  \
# 0             0.380918                    10         1                 False
# 1             0.630720                     9         0                 False
# 2             0.531712                     7         0                 False
# 3             0.592552                     8         1                 False
# 4             0.744634                    12         0                 False
#
#    pay_schedule_semi-monthly  pay_schedule_weekly
# 0                      False                False
# 1                      False                 True
# 2                      False                 True
# 3                      False                False
# 4                       True                False
#
# [5 rows x 23 columns]

# %%
dataset.shape
# Out:
# (17908, 23)

# %%
len(dataset.select_dtypes(include='object').columns)
# Out:
# 0

# %%
(dataset.e_signed ==1).sum()
# Out:
# np.int64(9639)

# %%
dataset.head()
# Out:
#    Entry_id  age  home_owner  income  months_employed  years_employed  \
# 0   7629673   40           1    3135                0               3
# 1   3560428   61           0    3180                0               6
# 2   6934997   23           0    1540                6               0
# 3   5682812   40           0    5230                0               6
# 4   5335819   33           0    3590                0               5
#
#    current_address_year  personal_account_m  personal_account_y  has_debt  \
# 0                     3                   6                   2         1
# 1                     3                   2                   7         1
# 2                     0                   7                   1         1
# 3                     1                   2                   7         1
# 4                     2                   2                   8         1
#
#    ...  risk_score_3  risk_score_4  risk_score_5  ext_quality_score  \
# 0  ...      0.903517      0.487712      0.515977           0.580918
# 1  ...      0.881027      0.713423      0.826402           0.730720
# 2  ...      0.766554      0.595018      0.762284           0.531712
# 3  ...      0.960832      0.767828      0.778831           0.792552
# 4  ...      0.857560      0.613487      0.665523           0.744634
#
#    ext_quality_score_2  inquiries_last_month  e_signed  pay_schedule_monthly  \
# 0             0.380918                    10         1                 False
# 1             0.630720                     9         0                 False
# 2             0.531712                     7         0                 False
# 3             0.592552                     8         1                 False
# 4             0.744634                    12         0                 False
#
#    pay_schedule_semi-monthly  pay_schedule_weekly
# 0                      False                False
# 1                      False                 True
# 2                      False                 True
# 3                      False                False
# 4                       True                False
#
# [5 rows x 23 columns]

# %%
dataset['months_employed']=dataset.months_employed+dataset.years_employed*12

# %%
dataset.head()
# Out:
#    Entry_id  age  home_owner  income  months_employed  years_employed  \
# 0   7629673   40           1    3135               36               3
# 1   3560428   61           0    3180               72               6
# 2   6934997   23           0    1540                6               0
# 3   5682812   40           0    5230               72               6
# 4   5335819   33           0    3590               60               5
#
#    current_address_year  personal_account_m  personal_account_y  has_debt  \
# 0                     3                   6                   2         1
# 1                     3                   2                   7         1
# 2                     0                   7                   1         1
# 3                     1                   2                   7         1
# 4                     2                   2                   8         1
#
#    ...  risk_score_3  risk_score_4  risk_score_5  ext_quality_score  \
# 0  ...      0.903517      0.487712      0.515977           0.580918
# 1  ...      0.881027      0.713423      0.826402           0.730720
# 2  ...      0.766554      0.595018      0.762284           0.531712
# 3  ...      0.960832      0.767828      0.778831           0.792552
# 4  ...      0.857560      0.613487      0.665523           0.744634
#
#    ext_quality_score_2  inquiries_last_month  e_signed  pay_schedule_monthly  \
# 0             0.380918                    10         1                 False
# 1             0.630720                     9         0                 False
# 2             0.531712                     7         0                 False
# 3             0.592552                     8         1                 False
# 4             0.744634                    12         0                 False
#
#    pay_schedule_semi-monthly  pay_schedule_weekly
# 0                      False                False
# 1                      False                 True
# 2                      False                 True
# 3                      False                False
# 4                       True                False
#
# [5 rows x 23 columns]

# %%
dataset=dataset.drop(columns=['years_employed'])

# %%
dataset.head()
# Out:
#    Entry_id  age  home_owner  income  months_employed  current_address_year  \
# 0   7629673   40           1    3135               36                     3
# 1   3560428   61           0    3180               72                     3
# 2   6934997   23           0    1540                6                     0
# 3   5682812   40           0    5230               72                     1
# 4   5335819   33           0    3590               60                     2
#
#    personal_account_m  personal_account_y  has_debt  amount_requested  ...  \
# 0                   6                   2         1               550  ...
# 1                   2                   7         1               600  ...
# 2                   7                   1         1               450  ...
# 3                   2                   7         1               700  ...
# 4                   2                   8         1              1100  ...
#
#    risk_score_3  risk_score_4  risk_score_5  ext_quality_score  \
# 0      0.903517      0.487712      0.515977           0.580918
# 1      0.881027      0.713423      0.826402           0.730720
# 2      0.766554      0.595018      0.762284           0.531712
# 3      0.960832      0.767828      0.778831           0.792552
# 4      0.857560      0.613487      0.665523           0.744634
#
#    ext_quality_score_2  inquiries_last_month  e_signed  pay_schedule_monthly  \
# 0             0.380918                    10         1                 False
# 1             0.630720                     9         0                 False
# 2             0.531712                     7         0                 False
# 3             0.592552                     8         1                 False
# 4             0.744634                    12         0                 False
#
#    pay_schedule_semi-monthly  pay_schedule_weekly
# 0                      False                False
# 1                      False                 True
# 2                      False                 True
# 3                      False                False
# 4                       True                False
#
# [5 rows x 22 columns]

# %%
dataset['personal_account_months']=dataset.personal_account_m+dataset.personal_account_y*12

# %%
dataset.head()
# Out:
#    Entry_id  age  home_owner  income  months_employed  current_address_year  \
# 0   7629673   40           1    3135               36                     3
# 1   3560428   61           0    3180               72                     3
# 2   6934997   23           0    1540                6                     0
# 3   5682812   40           0    5230               72                     1
# 4   5335819   33           0    3590               60                     2
#
#    personal_account_m  personal_account_y  has_debt  amount_requested  ...  \
# 0                   6                   2         1               550  ...
# 1                   2                   7         1               600  ...
# 2                   7                   1         1               450  ...
# 3                   2                   7         1               700  ...
# 4                   2                   8         1              1100  ...
#
#    risk_score_4  risk_score_5  ext_quality_score  ext_quality_score_2  \
# 0      0.487712      0.515977           0.580918             0.380918
# 1      0.713423      0.826402           0.730720             0.630720
# 2      0.595018      0.762284           0.531712             0.531712
# 3      0.767828      0.778831           0.792552             0.592552
# 4      0.613487      0.665523           0.744634             0.744634
#
#    inquiries_last_month  e_signed  pay_schedule_monthly  \
# 0                    10         1                 False
# 1                     9         0                 False
# 2                     7         0                 False
# 3                     8         1                 False
# 4                    12         0                 False
#
#    pay_schedule_semi-monthly  pay_schedule_weekly  personal_account_months
# 0                      False                False                       30
# 1                      False                 True                       86
# 2                      False                 True                       19
# 3                      False                False                       86
# 4                       True                False                       98
#
# [5 rows x 23 columns]

# %%
dataset=dataset.drop(columns=['personal_account_m','personal_account_y'])
dataset.head()
# Out:
#    Entry_id  age  home_owner  income  months_employed  current_address_year  \
# 0   7629673   40           1    3135               36                     3
# 1   3560428   61           0    3180               72                     3
# 2   6934997   23           0    1540                6                     0
# 3   5682812   40           0    5230               72                     1
# 4   5335819   33           0    3590               60                     2
#
#    has_debt  amount_requested  risk_score  risk_score_2  ...  risk_score_4  \
# 0         1               550       36200      0.737398  ...      0.487712
# 1         1               600       30150      0.738510  ...      0.713423
# 2         1               450       34550      0.642993  ...      0.595018
# 3         1               700       42150      0.665224  ...      0.767828
# 4         1              1100       53850      0.617361  ...      0.613487
#
#    risk_score_5  ext_quality_score  ext_quality_score_2  inquiries_last_month  \
# 0      0.515977           0.580918             0.380918                    10
# 1      0.826402           0.730720             0.630720                     9
# 2      0.762284           0.531712             0.531712                     7
# 3      0.778831           0.792552             0.592552                     8
# 4      0.665523           0.744634             0.744634                    12
#
#    e_signed  pay_schedule_monthly  pay_schedule_semi-monthly  \
# 0         1                 False                      False
# 1         0                 False                      False
# 2         0                 False                      False
# 3         1                 False                      False
# 4         0                 False                       True
#
#    pay_schedule_weekly  personal_account_months
# 0                False                       30
# 1                 True                       86
# 2                 True                       19
# 3                False                       86
# 4                False                       98
#
# [5 rows x 21 columns]

# %%
dataset.head()
# Out:
#    Entry_id  age  home_owner  income  months_employed  current_address_year  \
# 0   7629673   40           1    3135               36                     3
# 1   3560428   61           0    3180               72                     3
# 2   6934997   23           0    1540                6                     0
# 3   5682812   40           0    5230               72                     1
# 4   5335819   33           0    3590               60                     2
#
#    has_debt  amount_requested  risk_score  risk_score_2  ...  risk_score_4  \
# 0         1               550       36200      0.737398  ...      0.487712
# 1         1               600       30150      0.738510  ...      0.713423
# 2         1               450       34550      0.642993  ...      0.595018
# 3         1               700       42150      0.665224  ...      0.767828
# 4         1              1100       53850      0.617361  ...      0.613487
#
#    risk_score_5  ext_quality_score  ext_quality_score_2  inquiries_last_month  \
# 0      0.515977           0.580918             0.380918                    10
# 1      0.826402           0.730720             0.630720                     9
# 2      0.762284           0.531712             0.531712                     7
# 3      0.778831           0.792552             0.592552                     8
# 4      0.665523           0.744634             0.744634                    12
#
#    e_signed  pay_schedule_monthly  pay_schedule_semi-monthly  \
# 0         1                 False                      False
# 1         0                 False                      False
# 2         0                 False                      False
# 3         1                 False                      False
# 4         0                 False                       True
#
#    pay_schedule_weekly  personal_account_months
# 0                False                       30
# 1                 True                       86
# 2                 True                       19
# 3                False                       86
# 4                False                       98
#
# [5 rows x 21 columns]

# %%
x=dataset.drop(columns=['Entry_id','e_signed'])

# %%
y=dataset['e_signed']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (14326, 19)

# %%
x_test.shape
# Out:
# (3582, 19)

# %%
y_train.shape
# Out:
# (14326,)

# %%
y_test.shape
# Out:
# (3582,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.00599126, -0.85634884, -0.24235846, ..., -0.35607494,
#          1.97682704,  0.36896493],
#        [-0.50989022, -0.85634884, -0.05259224, ..., -0.35607494,
#         -0.50586115, -0.28090617],
#        [-0.7618397 ,  1.16774842, -0.41214928, ..., -0.35607494,
#         -0.50586115,  0.19566597],
#        ...,
#        [ 0.16197506, -0.85634884, -0.46541699, ..., -0.35607494,
#         -0.50586115, -1.45067413],
#        [ 1.08578982, -0.85634884, -0.69846323, ...,  2.80839755,
#         -0.50586115,  3.83494409],
#        [-0.7618397 , -0.85634884, -0.36554004, ..., -0.35607494,
#         -0.50586115, -1.27737518]])

# %%
x_test
# Out:
# array([[-1.01378918, -0.85634884, -0.24235846, ...,  2.80839755,
#         -0.50586115, -0.32423091],
#        [-1.01378918, -0.85634884, -0.33557695, ..., -0.35607494,
#         -0.50586115,  0.19566597],
#        [ 0.24595822, -0.85634884, -0.59858627, ...,  2.80839755,
#         -0.50586115, -0.84412778],
#        ...,
#        [-0.08997442, -0.85634884, -0.41214928, ..., -0.35607494,
#         -0.50586115,  0.36896493],
#        [-0.25794074, -0.85634884, -0.25567539, ..., -0.35607494,
#         -0.50586115,  0.19566597],
#        [-0.08997442, -0.85634884, -0.72176785, ..., -0.35607494,
#          1.97682704,  1.75535659]])

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression(random_state=0)
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix , accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.5622557230597431

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 652, 1002],
#        [ 566, 1362]])

# %%
from sklearn.svm import SVC
classifier=SVC(random_state=0)
classifier.fit(x_train,y_train)
# Out:
# SVC(random_state=0)
